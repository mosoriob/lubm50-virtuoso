# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
matplotlib.style.use('ggplot')
# %matplotlib inline

df = pd.read_csv('/Users/mosorio/querys/results/s/all.csv')
means = df.mean()
print (means)
ax = df.plot.box()
ax.set_ylabel('Time [ms]')
ax.set_xlabel('Query') "  2"
# Out:
# q1    2874.000000
# q2     357.500000
# q3     107.916667
# q4    3126.000000
# q5    2062.500000
# q6    4042.916667
# dtype: float64
